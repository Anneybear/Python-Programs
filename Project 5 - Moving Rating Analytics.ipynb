# %%
import pandas as pd
import os

# %%
os.getcwd()
movies = pd.read_csv("P4-Movie-Ratings.csv")

# %%
len(movies) # 559 row
# Out:
# 559

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRatings',
       'Budgetmillion', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null object
# Genre              559 non-null object
# CriticRating       559 non-null int64
# AudienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Year               559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  Budgetmillion         Year
# count    559.000000       559.000000     559.000000   559.000000
# mean      47.309481        58.744186      50.236136  2009.152057
# std       26.413091        16.826887      48.731817     1.362632
# min        0.000000         0.000000       0.000000  2007.000000
# 25%       25.000000        47.000000      20.000000  2008.000000
# 50%       46.000000        58.000000      35.000000  2009.000000
# 75%       70.000000        72.000000      65.000000  2010.000000
# max       97.000000        96.000000     300.000000  2011.000000

# %%
movies.Film = movies.Film.astype("category")   #  change the data type

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null object
# CriticRating       559 non-null int64
# AudienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Year               559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre = movies.Genre.astype("category")
movies.Year = movies.Year.astype("category")

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# CriticRating       559 non-null int64
# AudienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories # find the unique values
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  Budgetmillion
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# jointplot

# %%
j = sns.jointplot(data = movies, x='CriticRating', y='AudienceRatings')

# %%
j = sns.jointplot(data = movies, x='CriticRating', y='AudienceRatings', kind='hex')

# %%
#<<< Chart 1

# %% [markdown]
# ---

# %%
# histograms

# %%
m1 = sns.distplot(movies.AudienceRatings, bins=15)

# %%
m1 = sns.distplot(movies.CriticRating, bins=15)

# %%
sns.set_style("darkgrid")
n1 = plt.hist(movies.AudienceRatings, bins=15)

# %%
#<<< Chart 2

# %%
n1 = plt.hist(movies.CriticRating, bins=15)

# %%
#<<< Chart 3

# %% [markdown]
# ---

# %%
# stacked histograms

# %%
h1 = plt.hist(movies.Budgetmillion)
plt.show()

# %%
movies[movies.Genre == 'Drama']
# Out:
#                     Film  Genre  CriticRating  AudienceRatings  Budgetmillion  \
# 10            88 Minutes  Drama             5               51             30
# 11    A Dangerous Method  Drama            79               89             20
# 13        A Serious Man   Drama            89               64              7
# 18          Albert Nobbs  Drama            53               43              8
# 23       All Good Things  Drama            33               64             20
# ..                   ...    ...           ...              ...            ...
# 529            War Horse  Drama            77               73             66
# 532  Water For Elephants  Drama            60               72             38
# 534     We Own the Night  Drama            55               63             21
# 541             Whip It   Drama            84               73             15
# 545        Winter's Bone  Drama            94               73              2
#
#      Year
# 10   2007
# ...

# %%
movies[movies.Genre == 'Drama'].Budgetmillion
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: Budgetmillion, Length: 101, dtype: int64

# %%
h2 = plt.hist(movies[movies.Genre == 'Drama'].Budgetmillion)
plt.show()

# %%
h3 = plt.hist(movies[movies.Genre == 'Action'].Budgetmillion)
plt.show()

# %%
h2 = plt.hist(movies[movies.Genre == 'Action'].Budgetmillion)
h3 = plt.hist(movies[movies.Genre == 'Drama'].Budgetmillion)
h4 = plt.hist(movies[movies.Genre == 'Thriller'].Budgetmillion)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].Budgetmillion, movies[movies.Genre == 'Drama'].Budgetmillion])
# Out:
# ([array([29., 43., 24., 14., 13., 14., 11.,  3.,  2.,  1.]),
#   array([65., 26.,  8.,  1.,  0.,  1.,  0.,  0.,  0.,  0.])],
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.hist([movies[movies.Genre == 'Action'].Budgetmillion, 
          movies[movies.Genre == 'Drama'].Budgetmillion,
          movies[movies.Genre == 'Thriller'].Budgetmillion],
          bins=15, stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list() #or list1 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].Budgetmillion)
    
p = plt.hist(list1, bins=30, stacked = True)
plt.show()

# %%
#<<< Chart 4

# %% [markdown]
# ---

# %%
# KDE plot - kernel density estimate plot

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings', fit_reg=False, hue='Genre',
                 size=6, aspect=1)

# %%
#KDE plot
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, shade=True, cmap='Reds')

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, shade=True, shade_lowest=False, cmap='Reds')

# %%
#tips:
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, shade=True, shade_lowest=False, cmap='Reds')

k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, cmap='Reds')

# %% [markdown]
# ---

# %%
#working with subplots()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# sns.set_style("ticks")
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
k2 = sns.kdeplot(movies.Budgetmillion, movies.AudienceRatings)

# %%
k2b = sns.kdeplot(movies.Budgetmillion, movies.CriticRating)

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))
k2 = sns.kdeplot(movies.Budgetmillion, movies.AudienceRatings, ax=axes[0])
k2b = sns.kdeplot(movies.Budgetmillion, movies.CriticRating, ax=axes[1])

# %%
f, axes = plt.subplots(1,2, figsize=(12,6), sharex=True)
k2 = sns.kdeplot(movies.Budgetmillion, movies.AudienceRatings, ax=axes[0])
k2b = sns.kdeplot(movies.Budgetmillion, movies.CriticRating, ax=axes[1])
k2.set(xlim = (-20,160))
# Out:
# [(-20, 160)]

# %% [markdown]
# ---

# %%
#ViolinPlots

# %%
w = sns.boxplot(data=movies, x='Genre', y='CriticRating')

# %%
z = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
w1 = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
z1 = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating')

# %% [markdown]
# ---

# %%
#Creating a facet grid

# %%
#g = sns.FacetGrid(movies, row='Genre', hue='Genre')
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')

# %%
# g = g.map
plt.scatter(movies.CriticRating, movies.AudienceRatings)

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter,'CriticRating', 'AudienceRatings')

# %%
# can populate with any type of chart. Example: histograms
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.hist,'Budgetmillion')

# %%
#back to scatterplots:
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter,'CriticRating', 'AudienceRatings', **kws)

# %%
#controlling axes and adding diagonals:
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter,'CriticRating', 'AudienceRatings', **kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100), c='gray', ls='--')
g.add_legend()

# %% [markdown]
# ---

# %%
# Buliding dashboards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# sns.set_style("ticks")
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("darkgrid")
f,axes = plt.subplots(2, 2, figsize=(15,15))
k2 = sns.kdeplot(movies.Budgetmillion, movies.AudienceRatings, ax=axes[0,0])
k2b = sns.kdeplot(movies.Budgetmillion, movies.CriticRating, ax=axes[0,1])
k2.set(xlim = (-20,160))
k2b.set(xlim = (-20,160))
z1 = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating',ax=axes[1,0])
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])
k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, cmap='Reds',ax=axes[1,1])
k1.set(xlim = (-20,160))
plt.show()

# %%
sns.set_style("darkgrid")
f,axes = plt.subplots(2, 2, figsize=(15,15))
k2 = sns.kdeplot(movies.Budgetmillion, movies.AudienceRatings, ax=axes[0,0])
k2b = sns.kdeplot(movies.Budgetmillion, movies.CriticRating, ax=axes[0,1])
k2.set(xlim = (-20,160))
k2b.set(xlim = (-20,160))
z1 = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating',ax=axes[1,0])

#tips
axes[1,1].hist(movies[movies.Genre == 'Action'].Budgetmillion)
#k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])
#k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, cmap='Reds',ax=axes[1,1])
#k1.set(xlim = (-20,160))
plt.show()

# %% [markdown]
# ---

# %%
# Styling Dashboards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# sns.set_style("ticks")
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("dark", {'axes.facecolor':'black'}) # set the backgroud color to black
f,axes = plt.subplots(2, 2, figsize=(15,15))
#plot[0,0]
k1 = sns.kdeplot(movies.Budgetmillion, movies.AudienceRatings,
                 shade=True, shade_lowest=True, cmap='inferno', ax=axes[0,0])
k1b = sns.kdeplot(movies.Budgetmillion, movies.AudienceRatings, cmap='cool', ax=axes[0,0])
#plot[0,1]
k2 = sns.kdeplot(movies.Budgetmillion, movies.CriticRating,
                 shade=True, shade_lowest=True, cmap='inferno', ax=axes[0,1])
k2b = sns.kdeplot(movies.Budgetmillion, movies.CriticRating, cmap='cool', ax=axes[0,1])
#plot[1,0]
k3 = sns.violinplot(data=movies, x='Year', y='Budgetmillion', palette='YlOrRd', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, shade=True, shade_lowest=False, cmap='Blues_r', ax=axes[1,1])
k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, cmap='gist_gray_r',ax=axes[1,1])

k1.set(xlim = (-20,160))
k2.set(xlim = (-20,160))
plt.show()

# %% [markdown]
# ---

# %%
#Thematic edits

# %%
list1 = list() #or list1 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].Budgetmillion)
sns.set_style("whitegrid")    
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)  #size of A4 paper
p = plt.hist(list1, bins=30, stacked = True)
plt.title('Movie Budget Distribution', fontsize=35, color='DarkBlue', fontname='Console')
#plt.xlabel=("Budget", fontsize=25, color='Green')  # add label to x axes
#plt.ylabel=("Number of Movies", fontsize=25, color='Red')  # add label to y axes
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(frameon=True, fancybox=True, shadow=True, framealpha=1, prop={size:20}) ------#edit the legend
plt.show()
# Out:
# findfont: Font family ['Console'] not found. Falling back to DejaVu Sans.

# %%
plt.figure()
x = [1,2]
y = [1,2]
plt.plot(x,y)
plt.xlabel('x-axis', fontsize=20)


plt.ylabel('y-axis', fontsize=20)
plt.suptitle('Graph Title', fontsize=30)
# Out:
# Text(0.5, 0.98, 'Graph Title')
